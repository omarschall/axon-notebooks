# %%
import sys
sys.path.append('/home/om2382/mft-theory/')
import numpy as np
import torch
import matplotlib.pyplot as plt
from importlib import reload
from LDR_dim import *
reload(util)

# %%
reload(util)

N = 2500

#define d and rho
d = 4*util.gen_spect(N, 0.8, power=2)
rho = 0.8*util.gen_spect(N, 0.5, power=2) - 0.4
plt.plot(d/d[0], label="d/d[0]")
plt.plot(rho, label="$\\rho$")
plt.legend()
plt.show()

#get effective g (determines dynamcis when rho = 0)
print("g_eff =", np.sqrt((d**2).mean().item()))

#sample weights
J = util.gen_LDR(d=d, rho=rho)

#run simulation
X = util.run_sim(
    T=2500, dt=0.05, T_eval=1, J=J.to(0), N_batch=10)

#plot empirical autocov
C = util.compute_C(torch.tanh(X.to(0)), 0).cpu()
plt.plot(C)
plt.xlim(-1, 25)
plt.show()
# Out:
# g_eff = 2.8150759450584157
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 21
#      17 J = util.gen_LDR(d=d, rho=rho)
#      19 #run simulation
#      20 X = util.run_sim(
# ---> 21     T=2500, dt=0.05, T_eval=1, J=J.to(0), N_batch=10)
#      23 #plot empirical autocov
#      24 C = util.compute_C(torch.tanh(X.to(0)), 0).cpu()
#
# File /share/apps/anaconda3-2023.07.03/lib/python3.11/site-packages/torch/cuda/__init__.py:239, in _lazy_init()
#     235     raise RuntimeError(
#     236         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     237         "multiprocessing, you must use the 'spawn' start method")
#     238 if not hasattr(torch._C, '_cuda_getDeviceCount'):
# --> 239     raise AssertionError("Torch not compiled with CUDA enabled")
#     240 if _cudart is None:
#     241     raise AssertionError(
#     242         "libcudart functions unavailable. It looks like you have a broken build?")
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
reload(util)

#define callback function for solving LDR DMFT
#(plots current DMFT estimate and empirical estimate in black)
def callback_fn(C_current, S_current, i):
    plt.plot(C_current.cpu()[::20])
    plt.plot(C, color='black')
    plt.xlim(-1, 25)
    if i >= 1 and i % 5 == 0:
        plt.show()

#run DMFT solver loop
dt = 0.05
C_dmft, S_dmft = util.solve_dmft(
    update_fn=(lambda C, S:
               util.update_LDR_sym(d.to(0), rho.to(0), C, S, N_samples=4096, dt=dt)),
    callback_fn=callback_fn,
    init_dt=dt,
    N_t=2048,
    num_iter=100,
    device=0,
    alpha=0.8)
# Out:
#   5%|██▏                                        | 5/100 [00:04<01:21,  1.17it/s]
#   9%|███▊                                       | 9/100 [00:08<01:22,  1.11it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_14690/390745650.py in <module>
#      12 #run DMFT solver loop
#      13 dt = 0.05
# ---> 14 C_dmft, S_dmft = util.solve_dmft(
#      15     update_fn=(lambda C, S:
#      16                util.update_LDR_sym(d.to(0), rho.to(0), C, S, N_samples=4096, dt=dt)),
#
# ~/Projects/LDR-Dimensionality/util.py in solve_dmft(update_fn, N_t, init_dt, num_iter, device, alpha, C_init, S_init, callback_fn)
#     172
#     173     for i in tqdm(range(num_iter)):
# --> 174         C_updated, S_updated = update_fn(C=C, S=S)
#     175         C = alpha * C_updated + (1 - alpha) * C
#     176         S = alpha * S_updated + (1 - alpha) * S
#
# /tmp/ipykernel_14690/390745650.py in <lambda>(C, S)
#      14 C_dmft, S_dmft = util.solve_dmft(
#      15     update_fn=(lambda C, S:
# ---> 16                util.update_LDR_sym(d.to(0), rho.to(0), C, S, N_samples=4096, dt=dt)),
#      17     callback_fn=callback_fn,
#      18     init_dt=dt,
#
# ~/Projects/LDR-Dimensionality/util.py in update_LDR_sym(d, rho, C, S, N_samples, dt)
#     146     eta = sample_gp(D, N_samples)
#     147     nk = int(50 / dt)
# --> 148     x = run_dynamics(eta, dt=dt, kernel=R[:nk])
#     149     phi = torch.tanh(x)
#     150
#
# ~/Projects/LDR-Dimensionality/util.py in run_dynamics(eta, dt, kernel)
#     109         nk_stop = i - start
#     110         kernel_contribution = dt * torch.trapz(
# --> 111             torch.tanh(torch.flip(x[:, start:i], dims=(1,))) * kernel[None, :nk_stop], dim=1
#     112         ) if nk_stop > 0 else 0.0
#     113         x[:, i] = (1 - dt) * x[:, i - 1] + dt * eta[:, i] + dt * kernel_contribution
#
# KeyboardInterrupt:
