# %%
import sys, os, pickle
sys.path.append('/home/om2382/mft-theory/')
from cluster import *
from core import *
from empirics import *
from functions import *
from ode_methods import *
from plotting import *
from theory import *
from utils import *
import matplotlib.pyplot as plt

# %%
### --- SET UP ALL CONFIGS --- ###
from itertools import product
n_seeds = 5
macro_configs = config_generator(N=[500, 1000, 2000])

micro_configs = tuple(product(macro_configs, list(range(n_seeds))))
prototype = False

### --- SELECT PARTICULAR CONFIG --- ###
try:
    i_job = int(os.environ['SLURM_ARRAY_TASK_ID']) - 1
except KeyError:
    i_job = 0
    prototype = True
params, i_seed = micro_configs[i_job]
i_config = i_job//n_seeds

new_random_seed_per_condition = True
if new_random_seed_per_condition:
    np.random.seed(i_job)
else: #Match random seeds across conditions
    np.random.seed(i_seed)

# %%
#Network size
N = 1000
#Random connectivity
g = 3.5
J = g * np.random.normal(0, 1/np.sqrt(N), (N, N))

#Structure
s = 2.6
sigma_diag = 1.6
sigma_off = 0.8
sigma_mn = np.array([[sigma_diag, -sigma_off],
                     [sigma_off, sigma_diag]])
sigma_mm = np.eye(2)
n_var = 4
sigma_nn = n_var * np.eye(2)

covariance_top = np.hstack([sigma_mm, sigma_mn])
covariance_bot = np.hstack([sigma_mn.T, sigma_nn])
covariance = np.vstack([covariance_top, covariance_bot])

loadings = np.random.multivariate_normal(np.zeros(4), covariance, size=N)

m1 = loadings[:,0]
m2 = loadings[:,1]
n1 = loadings[:,2]
n2 = loadings[:,3]
M = np.multiply.outer(m1, n1) + np.multiply.outer(m2, n2)

#Recompute orthogonal m1 and m2 for analysis
U, S, VT = np.linalg.svd(M)
m1 = U[:,0]
m2 = U[:,1]

#projection matrices
P_m = np.eye(N) - np.multiply.outer(m1, m1)/N - np.multiply.outer(m2, m2)/N
P_n = np.eye(N) - np.multiply.outer(n1, n1)/N - np.multiply.outer(n2, n2)/N
P_m1 = np.eye(N) - np.multiply.outer(m1, m1)/N
P_m2 = np.eye(N) - np.multiply.outer(m2, m2)/N
P_n1 = np.eye(N) - np.multiply.outer(n1, n1)/N
P_n2 = np.eye(N) - np.multiply.outer(n2, n2)/N

if False: #project out both ms and ns
    J_ = P_m.dot(J).dot(P_n)
if False: #do each projection individually in case of chance m-n correlations
    J_ = P_m2.dot(P_m1).dot(J).dot(P_n2).dot(P_n1)
if False: #project out only ms
    J_ = P_m2.dot(P_m1).dot(J)
if False: #just m1 and n1
    J_ = P_m1.dot(J).dot(P_n1)
if False: #just n1
    J_ = J.dot(P_n1)
if False: #do all projections
    J_ = P_m2.dot(P_m1).dot(P_n2).dot(P_n1).dot(J).dot(P_m2).dot(P_m1).dot(P_n2).dot(P_n1)
if True:
    J_ = J
    
#Combine into one connectivity
W = J_ + s*M / N
#W_ = J_ + s*M / N

# %%
rnn = Time_Cts_RNN(W, tanh, g=1)
ode_method = Euler(0.05)
sim = Simulation(rnn)
x_init = np.random.normal(0, 1/np.sqrt(N), N)
T = 1000
sim.run(T=T, ode_method=ode_method, x_init=x_init, monitors=['rnn.x', 't'], T_monitor=0.1*T,
        T_monitor_interval=10)
# Out:
# Progress: 10.0% complete
# Time Elapsed: 0.4s
#
# Progress: 20.0% complete
# Time Elapsed: 0.7s
#
# Progress: 30.0% complete
# Time Elapsed: 1.1s
#
# Progress: 40.0% complete
# Time Elapsed: 1.4s
#
# Progress: 50.0% complete
# Time Elapsed: 1.8s
#
# Progress: 60.0% complete
# Time Elapsed: 2.2s
#
# Progress: 70.0% complete
# Time Elapsed: 2.5s
#
# Progress: 80.0% complete
# Time Elapsed: 2.9s
#
# Progress: 90.0% complete
# Time Elapsed: 3.2s

# %%
if prototype:
    plt.figure()
    for i in range(20):
        plt.plot(sim.mons['t'], sim.mons['rnn.x'][:,i])
    #plt.ylim([-10, 10])
    
    #plt.figure()
    #proj = sim.mons['rnn.x'].dot(m)
    #plt.plot(sim.mons['t'], proj)

# %%
m = np.hstack([m1.reshape(-1, 1), m2.reshape(-1, 1)])

x = sim.mons['rnn.x']
k = np.linalg.pinv(m).dot(x.T)

# %%
if prototype:
    plt.plot(k[0], k[1], alpha=0.8, markersize=0.3)

# %%
U, S, VT = np.linalg.svd(x)
v1 = VT[0,:]
v2 = VT[1,:]
#l
#x_proj = VT[:2,:].dot(x.T)
M = np.array([v1, v2]).dot(np.array([m1,m2]).T)

alignment = np.linalg.norm(M) / np.sqrt(2)
#weights_spectrum, vecs = np.linalg.eig(W)
#x_perp = x - np.multiply.outer(x.dot(m1), m1) - np.multiply.outer(x.dot(m2), m2)
#x_perp = x - np.multiply.outer(x.dot(v1), v1) - np.multiply.outer(x.dot(v2), v2)

# %%
alignment
# Out:
# 0.3581077346837151

# %%
if prototype:
    eigs_J, vecs_J = np.linalg.eig(J)
    eigs_J_, vecs_J_ = np.linalg.eig(J_)

    plt.plot(np.real(eigs_J), np.imag(eigs_J), '.', color='C0', alpha=0.6)
    plt.plot(np.real(eigs_J_), np.imag(eigs_J_), '.', color='C1', alpha=0.6)
    plt.axis('equal')
    plt.xlim([-4.3, 4.3])
    plt.ylim([-4.3, 4.3])

# %%
#eigs, vecs = np.linalg.eig(W)

# %%
#mode_var = x.dot(vecs).var(0)

# %%
#for i in range(1000):
#    col = ('{}'.format(0.9 - mode_var[i] / np.amax(mode_var)))
#    plt.plot([np.real(eigs[i])], [np.imag(eigs[i])], '.', color=col)
#plt.axis('equal')
# Out:
# (-3.7850616826468713, 4.817136742385113, -3.844848019195224, 3.844848019195224)

# %%
#eigs, vecs = np.linalg.eig(W.dot(W.T))
#U_W, S_W, VT_W = np.linalg.svd(W)

# %%
#alignments = VT.dot(vecs[:,np.argsort(eigs)[::-1]])

# %%
#plt.imshow(alignments[:,:])
#plt.colorbar()

# %%
#cov = compute_empirical_covariance(x_perp)
#off_diags = cov[np.triu_indices(cov.shape[0], k = 1)]
#cov_mean = off_diags.mean()
#cov_std = off_diags.std()

# %%
#eigs, vecs = np.linalg.eig(cov)

# %%
#plt.plot(sorted(np.abs(eigs))[::-1], '.')

# %%
#proj = np.linalg.qr(np.random.normal(0, 1, (N,N)))[0][:2,:]
#random_k = proj.dot(x.T)
#plt.plot(random_k[0], random_k[1], alpha=0.8)

# %%
#fig, ax = plt.subplots(1, 2, figsize=(6, 3))
#U, S, VT = np.linalg.svd(x)
#x_p_proj = VT[:2,:].dot(x.T)
#ax[0].plot(x_p_proj[0], x_p_proj[1], alpha=0.8)
#ax[0].set_xlim([-600, 600])
#ax[0].set_ylim([-600, 600])
#ax[0].set_title('x 2 PCs')
#U, S, VT = np.linalg.svd(x_perp)
#x_p_proj = VT[:2,:].dot(x_perp.T)
#ax[1].plot(x_p_proj[0], x_p_proj[1], alpha=0.8)
#ax[1].set_xlim([-600, 600])
#ax[1].set_ylim([-600, 600])
#ax[1].set_title('x perp 2 PCs')
#fig.savefig('figs/residual_oscillations_PC_subtract.pdf')

# %%
#plt.plot(k[0], k[1], alpha=0.8, markersize=0.3)
#plt.xlim([450, 550])
#plt.ylim([550, 650])

# %%
#evals = np.array(sorted(np.abs(eigs))[::-1])
#processed_data = np.zeros(4000)
#processed_data[:len(evals)] = evals
processed_data = alignment
#processed_data = k
#processed_data = np.array([np.real(weights_spectrum), np.imag(weights_spectrum)]).T
#processed_data = np.array([cov_mean, cov_std])

sim.runs_x = x[-int(100/ode_method.dt):,:10].copy()
sim.times = sim.mons['t'][-int(100/ode_method.dt):].copy()

dT_cov = 1
dT_cov_steps = int(dT_cov/(ode_method.dt*sim.T_monitor_interval))
#PR_x = compute_approximate_participation_coefficient(x[::dT_cov_steps], n_derangments=50)
#sim.PR_x = PR_x

if not prototype:
    del sim.rnn.W
    del sim.mons['rnn.x']
    del sim.mons['t']

# %%
### --- SAVE RESULTS -- ###
result = {'sim': sim, 'i_seed': i_seed, 'config': params,
          'i_config': i_config, 'i_job': i_job}
try:
    result['processed_data'] = processed_data
except NameError:
    pass
    
try:
    save_dir = os.environ['SAVEDIR']
    if not os.path.exists(save_dir):
        os.mkdir(save_dir)
    save_path = os.path.join(save_dir, 'result_{}'.format(i_job))

    with open(save_path, 'wb') as f:
        pickle.dump(result, f)
except KeyError:
    pass

# %%
###Truncate file above
file_name = 'limit_cycles_decouple'
job_name = 'alignment_N_decouple_3'
project_dir = '/home/om2382/low-rank-dims/'
main_script_path = os.path.join(project_dir, 'cluster_main_scripts', job_name + '.py')
get_ipython().run_cell_magic('javascript', '', 'IPython.notebook.save_notebook()')
get_ipython().system('jupyter nbconvert --to script --no-prompt {}.ipynb'.format(file_name))
get_ipython().system('awk "/###Truncate/ {{exit}} {{print}}" {}.py'.format(file_name))
get_ipython().system('sed -i "/###Truncate/Q" {}.py'.format(file_name))
get_ipython().system('mv {}.py {}'.format(file_name, main_script_path))
# Out:
# [NbConvertApp] Converting notebook limit_cycles_decouple.ipynb to script
# [NbConvertApp] Writing 21163 bytes to limit_cycles_decouple.py
# awk: cmd. line:1: /###Truncate/ <IPython.core.autocall.ZMQExitAutocall object at 0x2adb9ea38f60> <built-in function print>
# awk: cmd. line:1:                       ^ syntax error
# awk: cmd. line:1: /###Truncate/ <IPython.core.autocall.ZMQExitAutocall object at 0x2adb9ea38f60> <built-in function print>
# awk: cmd. line:1:                                                                                ^ syntax error

# %%
###Submit job to cluster
n_jobs = len(micro_configs)
write_job_file(job_name, py_file_name='{}.py'.format(job_name), mem=16, n_hours=6)
job_script_path = os.path.join(project_dir, 'job_scripts', job_name + '.s')
job_id_1 = submit_job(job_script_path, n_jobs)
# Out:
# rm: cannot remove ‘/home/om2382/low-rank-dims/results/misc/alignment_N_decouple_3/result_*’: No such file or directory
# sending incremental file list
# mft-theory/
# mft-theory/.DS_Store
# mft-theory/.gitignore
# mft-theory/README.md
# mft-theory/__init__.py
# mft-theory/jupyter_notebook.py
# mft-theory/main.ipynb
# mft-theory/.idea/
# mft-theory/.idea/mft-theory.iml
# mft-theory/.idea/misc.xml
# mft-theory/.idea/modules.xml
# mft-theory/.idea/vanilla-rtrl.iml
# mft-theory/.idea/vcs.xml
# mft-theory/.idea/workspace.xml
# mft-theory/.idea/codeStyles/
# mft-theory/.idea/codeStyles/codeStyleConfig.xml
# mft-theory/.ipynb_checkpoints/
# mft-theory/.ipynb_checkpoints/main-checkpoint.ipynb
# mft-theory/cluster/
# mft-theory/cluster/__init__.py
# mft-theory/cluster/close_jupyter_notebook.py
# mft-theory/cluster/process_results.py
# mft-theory/cluster/start_jupyter_notebook.py
# mft-theory/cluster/submit_jobs.py
# mft-theory/cluster/sync_cluster.py
# mft-theory/core/
# mft-theory/core/Simulation.py
# mft-theory/core/Time_Cts_RNN.py
# mft-theory/core/__init__.py
# mft-theory/empirics/
# mft-theory/empirics/__init__.py
# mft-theory/empirics/dimensionality.py
# mft-theory/functions/
# mft-theory/functions/Function.py
# mft-theory/functions/__init__.py
# mft-theory/functions/mean_squared_error.py
# mft-theory/functions/tanh.py
# mft-theory/ode_methods/
# mft-theory/ode_methods/Euler.py
# mft-theory/ode_methods/ODE_Method.py
# mft-theory/ode_methods/RK4.py
# mft-theory/ode_methods/__init__.py
# mft-theory/plotting/
# mft-theory/plotting/__init__.py
# mft-theory/plotting/misc.py
# mft-theory/theory/
# mft-theory/theory/__init__.py
# mft-theory/theory/basic_dmft.py
# mft-theory/theory/cavity_method.py
# mft-theory/theory/theory_utils.py
# mft-theory/utils/
# mft-theory/utils/__init__.py
# mft-theory/utils/mathematical_tools.py
# mft-theory/utils/programming_tools.py
#
# sent 199,299 bytes  received 878 bytes  400,354.00 bytes/sec
# total size is 196,088  speedup is 0.98

# %%
###Get job status
get_ipython().system('squeue -u om2382')
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#            1565097    lkumar  jupyter   om2382  R      27:33      1 ax14

# %%
project_dir = '/home/om2382/low-rank-dims/'
job_name = 'alignment_N_decouple_3'
job_script_path = os.path.join(project_dir, 'job_scripts', job_name + '.s')
configs_array, results_array, key_order, sim_dict = unpack_processed_data(job_script_path)

# %%
for i in range(5):
    plt.plot(configs_array['N'], results_array[:,i], '.', color='C0')
plt.xticks(configs_array['N'])
plt.ylim([0,1])
plt.ylabel("alignment between PCs and m's")
# Out:
# Text(0, 0.5, "alignment between PCs and m's")

# %%
fig, ax = plt.subplots(20, 20, figsize=(20, 20))
theta = np.arange(0, 2*np.pi, 0.01)
for i in range(20):
    for j in range(20):
        ax[19-i,j].plot(results_array[i,j,0,0,:], results_array[i,j,0,1,:], '.', markersize=0.6, color='C0')
        #ax[i,j].set_xlim([-5.5, 5.5])
        #ax[i,j].set_ylim([-5.5, 5.5])
        ax[i,j].axis('off')
        ax[i,j].axis('equal')
fig.savefig('meeting_figs/g_s_dynamics.png', dpi=250)

# %%
fig, ax = plt.subplots(10, 10, figsize=(20, 20))
theta = np.arange(0, 2*np.pi, 0.01)
for i in range(10):
    for j in range(10):
        ax[9-i,j].plot(results_array[j,i,0,:,0], results_array[j,i,0,:,1], '.', color='C0')
        ax[9-i,j].plot(np.cos(theta), np.sin(theta), color='k')
        ax[9-i,j].axvline(x=1, color='k')
        #ax[i,j].set_xlim([-5.5, 5.5])
        #ax[i,j].set_ylim([-5.5, 5.5])
        ax[i,j].axis('off')
        ax[i,j].axis('equal')
        
fig.savefig('figs/no_decouple_spectra.pdf')

# %%
#next steps: look at trajectories and spectra as a function of 
#how much of J we project out of. Make sure we're in the fuzzy donut,
#then look at alignment of rotation with m1m2. Also review man

# %%
plt.imshow(results_array.mean(-1).T[::-1], cmap='Blues')
plt.xticks(list(range(10)), [np.round(s, 1) for s in configs_array['s']])
plt.yticks(list(range(9, -1, -1)), [np.round(s, 1) for s in configs_array['g']])
#plt.yticks([list(range(10)), configs_array['g']])
plt.colorbar()
plt.xlabel('s')
plt.ylabel('g')
# Out:
# Text(0, 0.5, 'g')

# %%
for i in range(5):
    plt.plot(configs_array['s'], results_array[:,i], '.', color='C0')

# %%
fig, ax = plt.subplots(20, 20, figsize=(20, 20))
for i in range(20):
    for j in range(20):
        ax[19-j,i].plot(results_array[i,j,0,0,::10],results_array[i,j,0,1,::10], '.', 'C0', markersize=0.8)
        ax[19-j,i].axis('equal')
        ax[19-j,i].axis('off')

# %%
fig, ax = plt.subplots(10, 1, figsize=(2, 12))
for i_s in range(10):
    for i_seed in range(5):
        PRs = []
        for i_g in range(10):
            PRs.append(sim_dict['{}_{}_{}'.format(configs_array['s'][i_s],
                                                  configs_array['g'][i_g],
                                                  i_seed)].PR_x)
        ax[i_s].plot(PRs, '.', color='C0')
        ax[i_s].set_ylim([0, 0.1])
    ax[i_s].axis('off')
#fig.savefig('figs/no_subtract_g_s_prs.pdf')

# %%
fig, ax = plt.subplots(10, 1, figsize=(2, 12))
for i_s in range(10):
    for i_seed in range(5):
        PRs = []
        for i_g in range(10):
            PRs.append(sim_dict['{}_{}_{}'.format(configs_array['s'][i_s],
                                                  configs_array['g'][i_g],
                                                  i_seed)].PR_x)
        ax[i_s].plot(PRs, '.', color='C0')
        ax[i_s].set_ylim([0, 0.1])

# %%
fig, ax = plt.subplots(3, 3, figsize=(10, 10))
for i in range(3):
    for j in range(3):
        ax[i,j].set_title('s = {}'.format(configs_array['s'][3*i + j]))
        for k in range(5):
            ax[i,j].plot(configs_array['N'],results_array[3*i + j,:,k,1], '.', color='C0')

for j in range(3):
    ax[-1,j].set_xlabel('N')
ax[0,0].set_ylabel('Std. Dev. of cov off-diagonals')

# %%
PRs = np.square(results_array[:,:,:,:].sum(-1)) / np.square(results_array[:,:,:,:]).sum(-1)
PR_trunk = np.square(results_array[:,:,:,2:].sum(-1)) / np.square(results_array[:,:,:,2:]).sum(-1)
all_PRs = np.concatenate([PRs, PR_trunk], axis=1)

# %%
fig, ax = plt.subplots(20, 6, figsize=(6, 20))
for i in range(20):
    for j in range(6):
        ax[i,j].plot(all_PRs[i,j,:]/(configs_array['N'][j % 3] - 2*(j>2)), '.')
        ax[i,j].axis('off')
        ax[i,j].axhline(y=0, color='k')
        ax[i,j].set_ylim([0,0.2])
#fig.suptitle('g = 17')
fig.savefig('figs/PR_truncate_comp.pdf')

# %%
fig, ax = plt.subplots(20, 3, figsize=(3, 20))
for i in range(20):
    for j in range(3):
        ax[i,j].plot(results_array[i,j,0,0,:], results_array[i,j,0,1,:], '.', alpha=0.8, markersize=0.3)
        ax[i,j].axis('off')
        ax[i,j].axis('equal')
        #ax[i,j].axhline(y=0, color='k')
        #ax[i,j].set_ylim([0,0.2])
#fig.suptitle('g = 17')
fig.savefig('figs/PR_truncate_traj.pdf')

# %%
fig, ax = plt.subplots(20, 3, figsize=(3, 10))
for i in range(20):
    for j in range(3):
        ax[i,j].plot(results_array[i,j,0,:configs_array['N'][j]], '.', markersize=0.8)
        ax[i,j].set_ylim([0, 1.2 * np.amax(results_array)])
        ax[i,j].axis('off')
fig.savefig('figs/cov_evals.png', format='png')

# %%
fig, ax = plt.subplots(3, 4, figsize=(4, 12))
for i in range(3):
    #ax[i,0].set_ylabel('g = {:2f}'.format(configs_array['g'][i]))
    for j in range(4):
        #ax[i,j].plot(results_array[i,j,0,::10], results_array[i,j,1,::10], markersize=0.3,alpha=0.8, linewidth=0.3)
        ax[i,j].plot(results_array[i,j,0,::10], results_array[i,j,1,::10], '.', markersize=0.3,alpha=0.8)
        ax[i,j].axis('equal')
        ax[i,j].axis('off')
        pr = sim_dict['{}_{}'.format(configs_array['N'][i], j)].PR_x
        ax[i,j].set_title('%.4f'%pr)
        #ax[i,j].set_title('{}_{}'.format(configs_array['N'][i], j))
#fig.suptitle('s = {}'.format(configs_array['g'][k]))

# %%
for k in range(5):
    fig, ax = plt.subplots(5, 4, figsize=(4, 15))
    for i in range(5):
        ax[i,0].set_ylabel('g = {:2f}'.format(configs_array['g'][i]))
        for j in range(4):
            #ax[i,j].plot(results_array[i,j,0,::10], results_array[i,j,1,::10], markersize=0.3,alpha=0.8, linewidth=0.3)
            ax[i,j].plot(results_array[i,k,j,0,::10], results_array[i,k,j,1,::10], '.', markersize=0.3,alpha=0.8)
            ax[i,j].axis('equal')
            ax[i,j].axis('off')
            #pr = sim_dict['{}_{}_{}'.format(configs_array['g'][i], configs_array['s'][k], j)].PR_x
            #ax[i,j].set_title('%.4f'%pr)
            ax[i,j].set_title('{}_{}'.format(configs_array['g'][i], configs_array['s'][k]))
#fig.suptitle('s = {}'.format(configs_array['g'][k]))

# %%
for i_key, key in enumerate(sim_dict.keys()):
    plt.figure()
    plt.plot(results_array[i_key,0,::1], results_array[i_key,1,::1], '.', markersize=0.3,alpha=0.8)
    plt.axis('equal')
    plt.title('pr = {}.'.format(sim_dict[key].PR_x))

# %%
for k in range(4):
    fig, ax = plt.subplots(5, 4, figsize=(4, 15))
    for i in range(5):
        ax[i,0].set_ylabel('g = {:2f}'.format(configs_array['g'][i]))
        for j in range(4):
            ax[i,j].plot(results_array[i,k,j,0,::10], results_array[i,k,j,1,::10], '.', markersize=0.2,alpha=0.2)
            ax[i,j].axis('equal')
            ax[i,j].axis('off')
    fig.suptitle('s = {}'.format(configs_array['s'][k]))
    #fig.savefig('figs/cycle_g_n={}'.format(configs_array['n'][k]))

# %%
for k in range(3):
    fig, ax = plt.subplots(20, 4, figsize=(4, 15))
    for i in range(20):
        ax[i,0].set_ylabel('g = {:2f}'.format(configs_array['g'][i]))
        for j in range(4):
            ax[i,j].plot(results_array[i,k,j,0,::10], results_array[i,k,j,1,::10], '.', markersize=0.2,alpha=0.2)
            ax[i,j].axis('equal')
            ax[i,j].axis('off')
    fig.suptitle('N = {}'.format(configs_array['n'][k]))
    fig.savefig('figs/cycle_g_n={}'.format(configs_array['n'][k]))

# %%
# !ls figs/

# %%
fig, ax = plt.subplots(1, 6, figsize=(15, 5))
for i_ax in range(6):
    for i_seed in range(10):
        ax[i_ax].plot(configs_array['structure'], results_array[i_ax,:,i_seed,0], '.', color='k')
        ax[i_ax].plot(configs_array['structure'], results_array[i_ax,:,i_seed,1], '.', color='C3')

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
for i_ax in range(2):
    for i_seed in range(10):
        ax[i_ax].plot(configs_array['g'], results_array[i_ax,:,i_seed,0], '.', color='k')
        ax[i_ax].plot(configs_array['g'], results_array[i_ax,:,i_seed,1], '.', color='C3')

# %%
fig, ax = plt.subplots(1, 3, figsize=(10, 3))
for i_ax in range(3):
    ax[i_ax].set_title('N = {}'.format(configs_array['N'][i_ax]))
    for i_seed in range(10):
        ax[i_ax].plot(configs_array['structure'], results_array[i_ax,:,i_seed], '.', color='k')

# %%
fig, ax = plt.subplots(1, 2, figsize=(7, 3))
for i_ax in range(2):
    ax[i_ax].set_title('N = {}'.format(configs_array['N'][i_ax]))
    for i_seed in range(10):
        ax[i_ax].plot(configs_array['structure'], results_array[i_ax,:,i_seed], '.', color='k')

# %%
plt.plot(configs_array['structure'], results_array[:,:,0].mean(1), '.', color='k')
plt.plot(configs_array['structure'], results_array[:,:,1].mean(1), '.', color='r')
plt.xlabel(key_order[0])

# %%
for i in range(10):
    plt.plot(configs_array['structure'], results_array[:,i,0], '.', color='k')
    #plt.plot(configs_array['structure'], results_array[:,i,1], '.', color='r')
plt.xlabel(key_order[0])
plt.ylabel('$PR_x$')
plt.title('N = 1000, g = 2.25')

# %%
theory = []
for g in configs_array['g']:
    theory.append(solve_for_Delta_0(g))
#plt.plot(configs_array['g'], theory, color='k')
for i in range(len(configs_array['n'])):
    fig = plt.figure()
    plt.plot(configs_array['g'], theory, color='k')
    for j in range(len(configs_array['i_seed'])):
        plt.plot(configs_array['g'], results_array[i, :, j], '.', color='C{}'.format(i))
    plt.xlabel('g')
    plt.ylabel('$\Delta_0$')
    plt.title('n = {}'.format(configs_array['n'][i]))
    plt.xticks(configs_array['g'])
    plt.ylim([-0.05, 3.5])
    fig.savefig('figs/delta0_n={}.pdf'.format(configs_array['n'][i]), format='pdf')

# %%
def plot_2d_array_of_time_series(configs_array, results_array, common_ylim=None):
    
    n_x, n_y, n_seeds, n_t = results_array.shape[:]
    keys = [key for key in configs_array.keys()]
    fig, ax = plt.subplots(n_x, n_y, figsize=(10,10))
    for i in range(n_x):
        for j in range(n_y):
            for k in range(n_seeds):
                ax[i, j].plot(results_array[i,j,k,:], color='C0')
            if common_ylim is not None:
                ax[i, j].set_ylim(common_ylim)
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[0, j].set_title('{} = {}'.format(keys[1], configs_array[keys[1]][j]))
            ax[i, 0].set_ylabel('{} = {}'.format(keys[0], configs_array[keys[0]][i]))

# %%
plot_2d_array_of_time_series(configs_array, results_array)

# %%
results_array.shape
fig, ax = plt.subplots(4, 3, figsize=(10, 10))
for i in range(4):
    for j in range(3):
        for k in range(5):
            ax[i,j].plot(results_array[i,j,k,::100], color='C0')
            #ax[i,j].set_ylim([-0.01, 0.01])

#fig.savefig('figs/n_ginit.pdf', format='pdf')

# %%
fig = plot_3d_or_4d_array_of_config_results(configs_array, results_array, key_order,
                                            tick_rounding=5, vmin=0, vmax=0.02, cmap='Blues')
#fig.savefig('figs/T_n_dt_pr.pdf')

# %%
results_array.shape

# %%
fig = plt.figure()
colors = ['k', 'C3']
#colors = ['g', 'y']
for i_pr, pr in enumerate(['Demeaned X', 'X', 'Demeaned Phi', 'Phi']):
    for i_seed, seed in enumerate(configs_array['i_seed']):
        plt.plot(configs_array['structure'], results_array[:, 9, i_seed, i_pr], '.', color=colors[i_pr//2])
plt.xticks(configs_array['structure'])
plt.ylim([0, 0.03])
plt.xticks([0, 1, 2, 3, 4])
plt.xlabel('mn/N')
plt.ylabel('$PR$')
#plt.axhline(y=0.0602, color='k', linestyle='--')
#plt.axhline(y=0.126, color='k', linestyle='--')
#fig.savefig('figs/mean_demeaned_structure_pr.pdf')

# %%
fig, ax = plt.subplots(16, 16, figsize=(30, 30))
for i in range(10):
    for i_s, s in enumerate(configs_array['structure']):
        for i_g, g in enumerate(configs_array['g']):
            ax[15 - i_s, i_g].plot(sim_dict['{}_{}_0'.format(s, g)].runs_x[:,i], color='C{}'.format(i))
            ax[i_s, i_g].axis('off')
            #ax[i_s].axhline(y=sim_dict['{}_0'.format(s)].runs_x[:,i].mean(), color='C{}'.format(i))
            #ax[i_s].set_ylim([-3, 3])

# %%
#fig.savefig('figs/dim_bifurcations.pdf')

# %%
# !ls figs

# %%
fig, ax = plt.subplots(4, 4, figsize=(16, 16))
colors = ['k', 'C3']
for i_ax, g in enumerate(configs_array['g']):
    i_x = i_ax // 4
    i_y = i_ax % 4
    for i_pr, pr in enumerate(['Demeaned X', 'X', 'Demeaned Phi', 'Phi']):
        for i_seed, seed in enumerate(configs_array['i_seed']):
            ax[i_x, i_y].plot(configs_array['structure'], results_array[:, i_ax, i_seed, i_pr], '.', color=colors[i_pr//2])
    ax[i_x, i_y].set_xticks(configs_array['structure'])
    ax[i_x, i_y].set_ylim([-0.01, 0.08])
    ax[i_x, i_y].set_xticks([0, 1, 2, 3, 4])
    #ax[i_x, i_y].axis('off')
    ax[i_x, i_y].set_title('g = {}'.format(g))
    ax[i_x, i_y].set_xlabel('mn/N')
    plt.tight_layout()
