# %%
import torch
import time
import sys, os
sys.path.append('/home/om2382/mft-theory')
from cluster import *

# %%
if True:
    N = 8000
    iters = 100
    J = torch.randn((N, N)).to('cpu')
    x = torch.randn((N, 1)).to('cpu')
    t1 = time.time()
    for i in range(iters):
        x = torch.mm(J, x)
    t2 = time.time()
    print(t2 - t1)
# Out:
# 2.7709455490112305

# %%
print(torch.__version__)
# Out:
# 2.1.2

# %%
###Truncate file above
file_name = 'gpu_test'
job_name = 'test_gpu'
project_dir = '/home/om2382/low-rank-dims/'
main_script_path = os.path.join(project_dir, 'cluster_main_scripts', job_name + '.py')
get_ipython().run_cell_magic('javascript', '', 'IPython.notebook.save_notebook()')
get_ipython().system('jupyter nbconvert --to script --no-prompt {}.ipynb'.format(file_name))
get_ipython().system('awk "/###Truncate/ {{exit}} {{print}}" {}.py'.format(file_name))
get_ipython().system('sed -i "/###Truncate/Q" {}.py'.format(file_name))
get_ipython().system('mv {}.py {}'.format(file_name, main_script_path))
# Out:
# [NbConvertApp] Converting notebook gpu_test.ipynb to script
# [NbConvertApp] Writing 1450 bytes to gpu_test.py
# awk: cmd. line:1: /###Truncate/ <IPython.core.autocall.ZMQExitAutocall object at 0x2b66da0b4490> <built-in function print>
# awk: cmd. line:1:                       ^ syntax error
# awk: cmd. line:1: /###Truncate/ <IPython.core.autocall.ZMQExitAutocall object at 0x2b66da0b4490> <built-in function print>
# awk: cmd. line:1:                                                                                ^ syntax error

# %%
###Submit job to cluster
n_jobs = 1
write_job_file(job_name, py_file_name='{}.py'.format(job_name), mem=4, n_hours=1, n_gpus=1)
job_script_path = os.path.join(project_dir, 'job_scripts', job_name + '.s')
job_id_1 = submit_job(job_script_path, n_jobs)
# Out:
# rm: cannot remove ‘/home/om2382/low-rank-dims/results/misc/test_gpu/result_*’: No such file or directory
# sending incremental file list
# mft-theory/cluster/
# mft-theory/cluster/submit_jobs.py
#
# sent 10,032 bytes  received 54 bytes  20,172.00 bytes/sec
# total size is 199,671  speedup is 19.80

# %%
###Get job status
get_ipython().system('squeue -u om2382')
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#            1966982 burst,lku  jupyter   om2382 PD       0:00      1 (Resources)
#            1966983     burst  jupyter   om2382  R       4:45      1 ax05

# %%
# !cat ../logs/test_gpu

# %%
# !conda env list

# %%
# !squeue -u om2382
