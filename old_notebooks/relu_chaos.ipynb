# %%
import sys, os, pickle
import torch
sys.path.append('/home/om2382/mft-theory/')
from cluster import *
from core import *
from empirics import *
from functions import *
from LDR_dim import *
from ode_methods import *
from plotting import *
from theory import *
from utils import *
from functools import partial
import matplotlib.pyplot as plt

# %%
### --- SET UP ALL CONFIGS --- ###
from itertools import product
n_seeds = 1
macro_configs = config_generator(I=[0.01, 0.03, 0.1, 0.3, 1, 3],
                                 C_scale=list(np.round(np.arange(0.5, 2.1, 0.1), 2)))

micro_configs = tuple(product(macro_configs, list(range(n_seeds))))
prototype = False

### --- SELECT PARTICULAR CONFIG --- ###
try:
    i_job = int(os.environ['SLURM_ARRAY_TASK_ID']) - 1
except KeyError:
    i_job = 0
    prototype = True
params, i_seed = micro_configs[i_job]
i_config = i_job//n_seeds

new_random_seed_per_condition = True
if new_random_seed_per_condition:
    np.random.seed(i_job)
else: #Match random seeds across conditions
    np.random.seed(i_seed)

# %%
### --- Set empirical parameters --- ###

#network properties size
N = 2000
phi_torch = lambda x: torch.relu(x)
phi_prime_torch = lambda x: (x > 0).to(torch.float32)
g = 3
#lags window
T_window_emp = 1
dT_emp = 1
lags_emp = np.arange(0, T_window_emp, dT_emp)
n_lags_emp = int(T_window_emp/dT_emp)

# %%
#iid network

if False:

    mu = params['mu']
    dt = 0.05
    W_ = torch.from_numpy(np.random.normal(mu/N, g/np.sqrt(N), (N, N))).type(torch.FloatTensor).to(0)
    x, r = sample_activity(T_sim=600, dt_save=dt, dt=dt, W=W_, phi_torch=phi_torch,
                           runga_kutta=True, T_save_delay=200, input_current=params['I']*torch.ones(N)[None,:].to(0))

# %%
#low-rank network
sigma_diag = 1.6
sigma_off = 0.8
C_scale = params['C_scale']
#C_scale = 1
sigma_mn = C_scale*np.array([[sigma_diag, -sigma_off],
                                       [sigma_off, sigma_diag]])
sigma_mm = np.eye(2)
n_var = 10
sigma_nn = n_var * np.eye(2)

covariance_top = np.hstack([sigma_mm, sigma_mn])
covariance_bot = np.hstack([sigma_mn.T, sigma_nn])
covariance = np.vstack([covariance_top, covariance_bot])/N

#means = np.array([0, 0, params['mu'], params['mu']])/N
means = np.zeros(4)
loadings = np.random.multivariate_normal(means, covariance, size=N)

m1 = loadings[:,0]
m2 = loadings[:,1]
n1 = loadings[:,2]
n2 = loadings[:,3]
M = np.multiply.outer(m1, n1) + np.multiply.outer(m2, n2)

W_ = torch.from_numpy(M).type(torch.FloatTensor).to(0)
dt = 0.05
I = params['I']
#I = 0.3
x, r = sample_activity(T_sim=600, dt_save=dt, dt=dt, W=W_, phi_torch=phi_torch,
                       runga_kutta=True, T_save_delay=200, input_current=I*torch.ones(N)[None,:].to(0))

# %%
z = np.einsum('ti, ir -> tr', r, loadings)

# %%
processed_data = np.hstack([x[:5000,0][:,None], z[:5000]])

# %%
### --- SAVE RESULTS -- ###
result = {'sim': None, 'dim_emp': None,
          'i_seed': i_seed, 'config': params,
          'i_config': i_config, 'i_job': i_job}
try:
    result['processed_data'] = processed_data
except NameError:
    pass
    
try:
    save_dir = os.environ['SAVEDIR']
    if not os.path.exists(save_dir):
        os.mkdir(save_dir)
    save_path = os.path.join(save_dir, 'result_{}'.format(i_job))

    with open(save_path, 'wb') as f:
        pickle.dump(result, f)
except KeyError:
    pass

# %%
###Truncate file above
file_name = 'relu_chaos'
job_name = 'I_C_3'
project_dir = '/home/om2382/low-rank-dims/'
main_script_path = os.path.join(project_dir, 'cluster_main_scripts', job_name + '.py')
get_ipython().run_cell_magic('javascript', '', 'IPython.notebook.save_notebook()')
get_ipython().system('jupyter nbconvert --to script --no-prompt {}.ipynb'.format(file_name))
get_ipython().system('awk "/###Truncate/ {{exit}} {{print}}" {}.py'.format(file_name))
get_ipython().system('sed -i "/###Truncate/Q" {}.py'.format(file_name))
get_ipython().system('mv {}.py {}'.format(file_name, main_script_path))
# Out:
# [NbConvertApp] Converting notebook relu_chaos.ipynb to script
# [NbConvertApp] Writing 5546 bytes to relu_chaos.py
# awk: cmd. line:1: /###Truncate/ <IPython.core.autocall.ZMQExitAutocall object at 0x2b3727289c10> <built-in function print>
# awk: cmd. line:1:                       ^ syntax error
# awk: cmd. line:1: /###Truncate/ <IPython.core.autocall.ZMQExitAutocall object at 0x2b3727289c10> <built-in function print>
# awk: cmd. line:1:                                                                                ^ syntax error

# %%
###Submit job to cluster
n_jobs = len(micro_configs)
write_job_file(job_name, py_file_name='{}.py'.format(job_name), mem=64, n_hours=24, n_gpus=1,
               results_subdir='misc')
job_script_path = os.path.join(project_dir, 'job_scripts', job_name + '.s')
submit_job(job_script_path, n_jobs, execute=False,
           results_subdir='misc', lkumar=True)
# Out:
# rm: cannot remove ‘/home/om2382/low-rank-dims/results/misc/I_C_3/result_*’: No such file or directory
# sending incremental file list
# mft-theory/
# mft-theory/.DS_Store
# mft-theory/.gitignore
# mft-theory/README.md
# mft-theory/__init__.py
# mft-theory/jupyter_notebook.py
# mft-theory/main.ipynb
# mft-theory/.idea/
# mft-theory/.idea/mft-theory.iml
# mft-theory/.idea/misc.xml
# mft-theory/.idea/modules.xml
# mft-theory/.idea/vanilla-rtrl.iml
# mft-theory/.idea/vcs.xml
# mft-theory/.idea/workspace.xml
# mft-theory/.idea/codeStyles/
# mft-theory/.idea/codeStyles/codeStyleConfig.xml
# mft-theory/.ipynb_checkpoints/
# mft-theory/.ipynb_checkpoints/main-checkpoint.ipynb
# mft-theory/LDR_dim/
# mft-theory/LDR_dim/__init__.py
# mft-theory/LDR_dim/extensive_tasks.py
# mft-theory/LDR_dim/solve_ldr.ipynb
# mft-theory/LDR_dim/util.py
# mft-theory/LDR_dim/LDR-dim/
# mft-theory/LDR_dim/LDR-dim/__init__.py
# mft-theory/LDR_dim/LDR-dim/solve_ldr.ipynb
# mft-theory/LDR_dim/LDR-dim/util.py
# mft-theory/cluster/
# mft-theory/cluster/__init__.py
# mft-theory/cluster/close_jupyter_notebook.py
# mft-theory/cluster/process_results.py
# mft-theory/cluster/start_jupyter_notebook.py
# mft-theory/cluster/submit_jobs.py
# mft-theory/cluster/sync_cluster.py
# mft-theory/core/
# mft-theory/core/Estimate_Cov.py
# mft-theory/core/Estimate_Psi.py
# mft-theory/core/Estimate_Single_Unit_Prop.py
# mft-theory/core/Sample_Activity.py
# mft-theory/core/Simulation.py
# mft-theory/core/Time_Cts_RNN.py
# mft-theory/core/Torch_Sim.py
# mft-theory/core/Update_Step.py
# mft-theory/core/__init__.py
# mft-theory/empirics/
# mft-theory/empirics/__init__.py
# mft-theory/empirics/dimensionality.py
# mft-theory/functions/
# mft-theory/functions/Function.py
# mft-theory/functions/__init__.py
# mft-theory/functions/mean_squared_error.py
# mft-theory/functions/tanh.py
# mft-theory/ode_methods/
# mft-theory/ode_methods/Euler.py
# mft-theory/ode_methods/ODE_Method.py
# mft-theory/ode_methods/RK4.py
# mft-theory/ode_methods/__init__.py
# mft-theory/plotting/
# mft-theory/plotting/__init__.py
# mft-theory/plotting/misc.py
# mft-theory/theory/
# mft-theory/theory/__init__.py
# mft-theory/theory/basic_dmft.py
# mft-theory/theory/cavity_method.py
# mft-theory/theory/david_dmft.py
# mft-theory/theory/low_rank_dmft.py
# mft-theory/theory/theory_utils.py
# mft-theory/training/
# mft-theory/training/RNN_function.py
# mft-theory/training/Sample_GP.py
# mft-theory/training/__init__.py
# mft-theory/training/plotting.py
# mft-theory/utils/
# mft-theory/utils/__init__.py
# mft-theory/utils/mathematical_tools.py
# mft-theory/utils/programming_tools.py
#
# sent 476,613 bytes  received 1,267 bytes  318,586.67 bytes/sec
# total size is 471,887  speedup is 0.99
# sbatch  --array=1-96 -A lkumar -p lkumar /home/om2382/low-rank-dims/job_scripts/I_C_3.s

# %%
###Get job status
get_ipython().system('squeue -u om2382')
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#            3796158    lkumar  jupyter   om2382  R    1:06:51      1 ax14

# %%
project_dir = '/home/om2382/low-rank-dims/'
job_name = 'g_mu_I_3'
job_script_path = os.path.join(project_dir, 'job_scripts', job_name + '.s')
results = unpack_processed_data(job_script_path, results_subdir='PRL_Submission')

# %%
# !ls -t ../job_scripts/
# Out:
# I_C_3.s				       n=4k_usv_spectra.s
# I_C_2.s				       n=6k_usv_spectra.s
# I_C.s				       psi_somp_usv.s
# g_mu_I_4.s			       cavity_current_estimates.s
# g_mu_I_3.s			       prv_spectra_usv.s
# g_mu_I_2.s			       autocov_check.s
# g_I.s				       cheap_low_rank_prv.s
# g_mu_I.s			       step_cutoffs_spectra_4.s
# cosyne_sim_results_2.s		       step_cutoffs_spectra_3.s
# cosyne_sim_results.s		       step_cutoffs_autocovs_3.s
# cosyne_sim_results_test.s	       step_cutoffs_spectra_2.s
# double_Crr.s			       step_cutoffs_autocovs_2.s
# g_alpha_explore.s		       step_cutoffs_autocovs.s
# small_g_big_alpha.s		       step_cutoffs_g_somp.s
# sigma_sigma_g_alpha.s		       step_cutoffs_g.s
# sigma_sigma_g_4.s		       step_cutoffs.s
# LDR_sym_alpha5_2.s		       psi00_match_3.s
# sigma_sigma_g_3.s		       psi_00_usv_match.s
# LDR_sym_alpha5.s		       psi00_match_2.s
# sigma_sigma_g_2.s		       psi00_match.s
# sigma_sigma_g.s			       exp_step_comp_3.s
# intensive_extensive_full.s	       exp_step_comp_2.s
# intensive_extensive_test.s	       exp_step_comp.s
# intensive_extensive.s		       gS4_PR_3.s
# large_output_pulse_N_in.s	       g_S_4_PR_2.s
# mini_2_output_pulse_N_in.s	       g_S_4_PR_1.s
# mini_output_pulse_N_in.s	       g_S_4_autocov_2.s
# recycle_pulse_N_in.s		       g_S_4_autocov.s
# recycle_pulse_2.s		       usv_autocov_3.s
# recycle_pulse.s			       usv_spec_S.s
# zero_init_W_Nin_Nepochs.s	       usv_autocov_2.s
# N_in_n_epochs_N5k.s		       usv_spec_2.s
# N_in_n_epochs_lr.s		       usv_spec.s
# N_in_N_N_train.s		       usv_power_expl_2.s
# third_try.s			       usv_power_expl.s
# second_try.s			       prv_sample_scaling_more_T.s
# first_try.s			       prv_sample_scaling.s
# LDR_sym_R_R1_R2.s		       spectrum_N_sample_scaling.s
# LDR_sym_R_check_2.s		       spectrum_N_scaling_2.s
# LDR_sym_R_check.s		       spectrum_N_scaling.s
# LDRG_PR_match_PRG_sim_final_3.s        spectra_scaling_N_2.s
# LDRG_spectra_step_D_final_2.s	       R_shift_spectral_decays.s
# Psi_PC_theory_sim.s		       g_spectral_decays_2.s
# LDRG_PR_match_PRG_sim_final_2.s        g_spectral_decays.s
# LDR_sym_PR_match_rho_sim_final_5.s     spectra_scaling_N.s
# LDRG_spectra_step_D_final.s	       spectra_scaling.s
# LDR_sym_PR_match_rho_theory_final_5.s  pr_check_fuzzy_donut_3.s
# LDR_sym_PR_match_rho_sim_final_4.s     pr_check_fuzzy_donut_2.s
# LDR_sym_PR_match_rho_theory_final_4.s  pr_check_fuzzy_donut.s
# LDR_sym_PR_match_rho_sim_final_3.s     g_s_ratio_check.s
# LDR_sym_PR_match_rho_theory_final_3.s  noises_g_bifuraction.s
# g_eff_slow_fast_decay.s		       kappaa_N_growth_2.s
# LDRG_spectra_step_D_3.s		       kappaa_N_growth.s
# LDRG_spectra_step_D_2.s		       alignment_N_growth_gpu_2.s
# LDRG_spectra_step_D.s		       alignment_N_growth_gpu.s
# LDR_sym_PR_match_rho_theory_final_2.s  delta_emp_gpu_test_2.s
# LDR_sym_Psi_match_rho_theory.s	       delta_emp_gpu_test.s
# LDR_sym_Psi_match_rho_sim.s	       test_gpu.s
# LDRG_spectra_comparison.s	       delta_emp_N=16k.s
# LDR_sym_PR_match_rho_sim_final.s       delta_emp_dist_g35_s13.s
# LDR_sym_PR_match_rho_theory_final.s    delta_emp_dist_g_s_13.s
# LDR_sym_PR_match_rho_theory_test_12.s  delta_emp_dist_g_s.s
# LDR_sym_PR_match_rho_sim_test_12.s     delta_emp_dist_N1k.s
# LDR_sym_PR_match_rho_sim_test_11.s     delta_emp_dist_N2k.s
# LDRG_PR_match_PRG_sim_final.s	       delta_emp_dist.s
# LDRG_Psi_match_PRD_theory_final.s      s_PS_dense_2.s
# LDRG_Psi_match_PRD_sim_final.s	       s_PS_dense.s
# LDRG_Psi_match_PRD_sim_3.s	       g_k_ps_3.s
# LDRG_Psi_match_PRD_theory_3.s	       g_x_ps_3.s
# LDRG_Psi_match_PRD_sim_2.s	       g_x_ps_2.s
# LDRG_Psi_match_PRD_theory_2.s	       g_x_ps.s
# LDRG_Psi_match_PRD_sim.s	       N_frequencies.s
# LDRG_Psi_match_PRD_theory.s	       g_frequencies.s
# LDRG_Psi_match_PRD_theory_test.s       alignment_N_decouple_3.s
# LDRG_PR_match_PRG_theory_final.s       alignment_N_decouple_2.s
# LDRG_PR_match_PRG_sim_test.s	       alignment_N_decouple.s
# LDRG_PR_match_PRD_theory_final.s       alignment_N_scaling.s
# LDRG_PR_match_PRD_sim_final.s	       dense_grid_s_g.s
# LDRG_PR_match_PRD_theory.s	       s_g_N_dim_subtract_big_data.s
# LDRG_PR_match_PRD_sim.s		       rebalance_s_g_8.s
# LDR_sym_PR_match_rho_theory_test_10.s  rebalance_s_g_7.s
# LDR_sym_PR_match_rho_sim_test_10.s     rebalance_s_g_6.s
# LDR_sym_PR_match_rho_theory_test_9.s   rebalance_s_g_5.s
# LDR_sym_PR_match_rho_sim_test_9.s      rebalance_s_g_4.s
# LDR_sym_PR_match_rho_theory_test_8.s   rebalance_s_g_3.s
# LDR_sym_PR_match_rho_sim_test_8.s      rebalance_s_g_2.s
# LDR_sym_PR_match_rho_theory_test_7.s   rebalance_s_g.s
# LDR_sym_PR_match_rho_sim_test_7.s      s_PC_alignment_random_part_n2k.s
# LDR_sym_PR_match_rho_theory_test_6.s   s_PC_alignment_random_part.s
# LDR_sym_PR_match_rho_sim_test_6.s      s_g_dynamics_no_decouple.s
# LDRG_PR_match_PRG_theory.s	       s_g_alignment_quart_decouple.s
# LDRG_PR_match_PRG_sim.s		       s_g_spectrum_quart_decouple.s
# LDR_sym_PR_match_rho_theory_test_5.s   s_g_spectrum_half_decouple.s
# LDR_sym_PR_match_rho_sim_test_5.s      s_g_alignment_half_decouple.s
# LDRG_PR_match_PRG_sim_check.s	       s_g_spectrum_decouple.s
# LDRG_PR_match_PRG_theory_check.s       s_g_spectrum_no_decouple.s
# LDRG_PR_match_PRG_theory_2.s	       s_g_alignment_grid_decouple.s
# LDRG_PR_match_PRG_sim_2.s	       s_g_alignment_grid_no_decouple.s
# LDRG_PRD_timescales.s		       s_vary_alignment_nm_decouple_full.s
# LDRG_PR_match_PRD_sim_test.s	       s_vary_alignment_nm_decouple.s
# LDR_sym_PR_match_rho_sim_test_4.s      s_vary_alignment.s
# LDR_sym_PR_match_rho_theory_test_4.s   s_g_4_k.s
# LDR_sym_PR_match_rho_theory_test_3.s   s_g_small_range_k_2.s
# LDR_sym_PR_match_rho_theory_test_2.s   s_g_small_range_k.s
# LDR_sym_PR_match_rho_theory_test.s     s_g_dim_no_subtract_big_data.s
# LDR_sym_PR_match_rho_theory_2.s        s_g_dim_no_subtract.s
# LDR_sym_PR_match_rho_sim_2.s	       s_g_dim.s
# linear_nonlinear_comp.s		       cov_stats_s_N.s
# sample_many_cov_chols_2.s	       cov_dist_s_N.s
# sample_many_cov_chols.s		       k_traj_vary_s_N.s
# LDR_sym_PR_match_rho_sim.s	       cov_spectra_vary_s_N.s
# LDR_sym_PR_match_rho_theory.s	       cov_spectra_vary_s.s
# LDR_sym_C_match_4.s		       proj_out_m1m2_smallN.s
# LDR_sym_C_match_3.s		       donut_N_vary_more_data.s
# LDR_sym_C_match_2.s		       donut_N_vary.s
# LDR_sym_C_match.s		       reliable_donut.s
# tiny_PRD_vs_tiny_PRG_g=20.s	       g_s_long_vary.s
# small_PRD_vs_small_PRG_g=20.s	       n4k_g15g2_dims.s
# small_PRD_vs_small_PRG.s	       n2k_g1_20_dims.s
# small_alpha_power_laws.s	       n1k_dims.s
# PR_G_theory_test.s		       n1p6k_dims.s
# LDRG_PR_match_PRG_2.s		       n8k.s
# PR_G_match_test.s		       n4k.s
# small_PR_D_2.s			       g_many_seeds.s
# small_PR_D.s			       g_s_grid.s
# LDR_sym_rho_theory_power_law.s	       fixed_scaling.s
# USV_LDR_USV_hemibrain.s		       g_n_vary.s
# LDR_sym_rho_theory_2.s		       g_large_range.s
# LDR_sym_rho_theory.s		       g_seed_n2000.s
# LDR_sym_psi_match_4.s		       g_limit_cycle.s
# LDR_sym_psi_match_3.s		       dim_rank_structure_scale.s
# LDR_sym_psi_match_2.s		       dim_rank_scale.s
# LDR_sym_psi_match.s		       dim_figure.s
# LDRG_PR_match_PRG.s		       g2p25_N_structure_pr_2.s
# LDRG_PR_match_alpha.s		       g2p25_N_structure_pr.s
# LDRG_PR_match_g.s		       g2p25_structure_pr_2.s
# LDRG_PR_match_2.s		       g2p25_structure_pr.s
# LDRG_PR_match.s			       efficient_autocov_2.s
# PR_G_PR_D_interp_4.s		       structure_g_pr_2.s
# PR_G_PR_D_interp_3.s		       efficient_autocov.s
# PR_G_PR_D_interp_2.s		       structure_g_pr.s
# PR_G_PR_D_interp.s		       structure_pr_2.s
# phase_transition_power_3.s	       structure_pr.s
# phase_transition_power_2.s	       Euler_means_phi_x_N1000_pr.s
# phase_transition_power.s	       RK4_means_phi_x_N1000_pr.s
# LDRG_match_attempt_4.s		       g_n2500_T3000_pr.s
# LDRG_match_attempt_3.s		       g_n2500_T5000_pr.s
# LDRG_fit_correction_2.s		       g_n5000_pr.s
# LDRG_fit_correction_1.s		       g_n1000_pr.s
# LDRG_match_attempt_2.s		       dt_T_n_efficiency_g20.s
# LDRG_match_attemp.s		       empirical_pr.s
# PRX_match_attempt_2.s		       g_structure_regimes.s
# PRX_match_attempt.s		       g_dz_theory.s
# alpha_spectra_x.s		       g_n_delta.s
# gamma_rho_spectra.s		       g_n_delta0.s
# alpha_beta_spectra_3.s		       g_n_chaos_2.s
# alpha_beta_spectra_2.s		       g_n_chaos.s
# alpha_beta_spectra.s		       x_init_mag.s
# vaziri_transpose.s		       n_ginit.s
# vaziri_t.s

# %%
fig, ax = plt.subplots(5, 16, figsize=(20, 10))
for i in range(5):
    for j in range(16):
        #ax[i,j].plot(results[1][i,j,0,:,0])
        ax[i,j].plot(results[1][i,j,0,:,0], results[1][i,j,0,:,1])
        #ax[i,j].set_xticks([])
        #ax[i,j].set_yticks([])

# %%
fig, ax = plt.subplots(5, 5, figsize=(12, 12))
for i in range(5):
    for j in range(5):
        ax[i,j].plot(results[1][i,j,0,:])

# %%
fig, ax = plt.subplots(8, 5, figsize=(20, 20))
print(results[0])
for i in range(8):
    for j in range(5):
        ax[i,j].plot(results[1][i,j,2,0])
# Out:
# {'g': [1.5, 2, 3, 4, 5, 6, 10, 20], 'I': [0, 0.01, 0.03, 0.1, 0.3], 'mu': [-1000, -300, -100, -30, -10, -3], 'i_seed': [0]}

# %%
fig, ax = plt.subplots(8, 10, figsize=(20, 20))
print(results[0])
for i in range(8):
    for j in range(10):
        ax[i,j].plot(results[1][i,j,2,0])
# Out:
# {'g': [1.5, 2, 3, 4, 5, 6, 10, 20], 'I': [-10, -3, -1, -0.3, 0, 0.1, 0.3, 1, 3, 10], 'mu': [-100, -30, -10, -3], 'i_seed': [0]}

# %%
fig, ax = plt.subplots(6, 10, figsize=(9, 6))
for i in range(6):
    for j in range(10):
        ax[i,j].plot(results[1][i,j,0,0])

# %%
fig, ax = plt.subplots(2, 5, figsize=(10, 4))
ax = ax.flatten()
for i in range(10):
    #ax[i].imshow(np.isnan(results[1]).any(-1)[:,:,i,0])
    ax[i].imshow(np.abs(results[1]>1).any(-1)[:,:,i,0])
